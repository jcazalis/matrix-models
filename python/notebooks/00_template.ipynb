# %%
from datetime import datetime

# Print the date and time of the last run (European format)
print("Last run:", datetime.now().strftime("%d.%m.%Y %H:%M:%S"))
# Out:
# Last run: 09.02.2026 16:50:07

# %% [markdown]
# ---
#
#     title:
#     author: Jean Cazalis
#     date: !today
#
# ---
#
# **Description:**
